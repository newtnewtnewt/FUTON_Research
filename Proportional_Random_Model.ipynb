# %%
from ipynb.fs.full.Final_Diagnostic_Model import aggregate_dataset_construct
from ipynb.fs.full.Final_Diagnostic_Model import zscores_for_train_and_test
import pandas as pd
import random as rng
import numpy as np

# %%
"""
# evaluate_pure_random_model simply evaluates the purely random models based on an even coin flip
# 
# Input:
# train_flag - Boolean flags for the rows to be included in the train data set
# test_flag - Boolean flags for the rows to be included in the test data set
# MIMIC_zscores - Z-Scores generated from the base data set: patientdata
# patientdata - The base data set to investigate
# test_name - The name of the test being conducted
# run_num - The number of the test run being calculated
# is_debug - Whether or not to include print statements in the code
# 
# Output: 
# N/A
# 
"""
def evaluate_pure_random_model(train_flag, test_flag, MIMIC_zscores, patientdata, test_name, run_num, is_debug):
    # Grab the unique icustays with their corresponding mortality rates
    train_set = patientdata[train_flag][['icustayid','mortality_90d']].drop_duplicates()
    test_set = patientdata[test_flag][['icustayid','mortality_90d']].drop_duplicates()
    total_alive:int = test_set['mortality_90d'].value_counts()[0]
    total_dead:int = test_set['mortality_90d'].value_counts()[1]
    # Construct a set of data to record
    death_states:List[int] = test_set['mortality_90d'].tolist()
    total_patients:int = len(death_states)
    correct_guesses:int = 0
    dead_instead_live:int = 0
    live_instead_dead:int = 0
    PATIENT_LIVED:int = 0
    PATIENT_DIED:int = 1
    # The Proportional Training set uses train and test data in order to fairly blind the 'model'
    total_alive_train = train_set['mortality_90d'].value_counts()[0]
    total_patients_train = len(train_set['mortality_90d'].tolist())
    alive_proportion:float = total_alive_train/total_patients_train
    print(alive_proportion)
    for i in range(0, total_patients):
        random_guess = 1
        # Generate proportional guess based on Randomly Uniform Distribution [0.0, 1.0]
        random_double = rng.random()
        # Suppose 60% of the people are alive. That means the code should say the person is alive
        # If a float between 0 and 0.5999999... is rolled, and dead otherwise
        if random_double < alive_proportion:
            random_guess = 0
        
        patient_status = death_states[i]
        # If the random guesser guesses correctly, add to the count
        if random_guess == patient_status:
            correct_guesses = correct_guesses + 1
        else:
            # If the patient was guessed alive when they died
            if patient_status == PATIENT_LIVED:
                live_instead_dead = live_instead_dead + 1
            # If the patient was guessed dead when they lived
            else:
                dead_instead_live = dead_instead_live + 1
    # Grab all the calculated values
    overall_accuracy:float = correct_guesses/total_patients
    dead_accuracy:float = (total_dead - dead_instead_live) / total_dead
    live_accuracy:float = (total_alive - live_instead_dead) / total_alive
    if is_debug:
        print("Test Name: " + test_name)
        print("Overall Accuracy: " + str(overall_accuracy))
        print("Accuracy for Dead: " + str(dead_accuracy))
        print("Accuracy for Living: " + str(live_accuracy))
        print("Living People Guessed Dead: " + str(live_instead_dead))
        print("Dead People Guessed Living: " + str(dead_instead_live))
        print("Total Patients: " + str(total_patients))
        print("Correct Guesses: " + str(correct_guesses))
        print("Alive People: " + str(total_alive))
        print("Dead People: " + str(total_dead))
        print("\n")
    # Construct a formatted CSV string with all the values that have been set
    total_string = (f'{run_num},{total_patients},{correct_guesses},'
                    f'{overall_accuracy},{dead_accuracy}'
                    f'{live_accuracy},{live_instead_dead},{dead_instead_live},'
                    f'{total_alive},{total_dead},'
                    f'{test_name}')
    if test_name == 'Test_Proportional_Random':
        with open('test_proportional_random_runs.csv', 'a') as f:
            f.write(total_string + "\n")

# %%
#  The Data File that will be used to conduct the experiments
patientdata:pd.DataFrame = pd.read_csv("G:/MIMIC-ALL/MIMIC-PATIENTS/patient_data_modified.csv")
    
# This is the run loop to execute and save the results to the file for the Q-Learning Weighted and Unweighted Model
if __name__ == "__main__":
    # Use the function from the Diagnostic Model to generate the stratified data sets
    train_flag_set, test_flag_set, MIMIC_zscores = aggregate_dataset_construct()
    # Set seed for random function
    rng.seed(123456789)
    for i in range(0, len(test_flag_set)):
        test_flag = test_flag_set[i]
        train_flag = train_flag_set[i]
        evaluate_pure_random_model(train_flag, test_flag, 
                                   MIMIC_zscores, patientdata, 
                                   test_name='Test_Proportional_Random', 
                                   run_num=i, is_debug=True)
# Out:
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5025879917184265
# Accuracy for Dead: 0.5175438596491229
# Accuracy for Living: 0.49796747967479676
# Living People Guessed Dead: 741
# Dead People Guessed Living: 220
# Total Patients: 1932
# Correct Guesses: 971
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4808488612836439
# Accuracy for Dead: 0.44298245614035087
# Accuracy for Living: 0.49254742547425473
# Living People Guessed Dead: 749
# Dead People Guessed Living: 254
# Total Patients: 1932
# Correct Guesses: 929
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5108695652173914
# Accuracy for Dead: 0.4934210526315789
# Accuracy for Living: 0.516260162601626
# Living People Guessed Dead: 714
# Dead People Guessed Living: 231
# Total Patients: 1932
# Correct Guesses: 987
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5134575569358178
# Accuracy for Dead: 0.5307017543859649
# Accuracy for Living: 0.508130081300813
# Living People Guessed Dead: 726
# Dead People Guessed Living: 214
# Total Patients: 1932
# Correct Guesses: 992
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.49585921325051757
# Accuracy for Dead: 0.4901098901098901
# Accuracy for Living: 0.4976303317535545
# Living People Guessed Dead: 742
# Dead People Guessed Living: 232
# Total Patients: 1932
# Correct Guesses: 958
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4989648033126294
# Accuracy for Dead: 0.5076923076923077
# Accuracy for Living: 0.4962762356127285
# Living People Guessed Dead: 744
# Dead People Guessed Living: 224
# Total Patients: 1932
# Correct Guesses: 964
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4904194717762817
# Accuracy for Dead: 0.5076923076923077
# Accuracy for Living: 0.48509485094850946
# Living People Guessed Dead: 760
# Dead People Guessed Living: 224
# Total Patients: 1931
# Correct Guesses: 947
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5199378560331435
# Accuracy for Dead: 0.5472527472527473
# Accuracy for Living: 0.5115176151761518
# Living People Guessed Dead: 721
# Dead People Guessed Living: 206
# Total Patients: 1931
# Correct Guesses: 1004
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.49611600207146556
# Accuracy for Dead: 0.4901098901098901
# Accuracy for Living: 0.49796747967479676
# Living People Guessed Dead: 741
# Dead People Guessed Living: 232
# Total Patients: 1931
# Correct Guesses: 958
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5121698601760746
# Accuracy for Dead: 0.512087912087912
# Accuracy for Living: 0.5121951219512195
# Living People Guessed Dead: 720
# Dead People Guessed Living: 222
# Total Patients: 1931
# Correct Guesses: 989
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5113871635610766
# Accuracy for Dead: 0.5307017543859649
# Accuracy for Living: 0.505420054200542
# Living People Guessed Dead: 730
# Dead People Guessed Living: 214
# Total Patients: 1932
# Correct Guesses: 988
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5067287784679089
# Accuracy for Dead: 0.5197368421052632
# Accuracy for Living: 0.502710027100271
# Living People Guessed Dead: 734
# Dead People Guessed Living: 219
# Total Patients: 1932
# Correct Guesses: 979
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4855072463768116
# Accuracy for Dead: 0.47368421052631576
# Accuracy for Living: 0.489159891598916
# Living People Guessed Dead: 754
# Dead People Guessed Living: 240
# Total Patients: 1932
# Correct Guesses: 938
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.49585921325051757
# Accuracy for Dead: 0.48464912280701755
# Accuracy for Living: 0.4993224932249323
# Living People Guessed Dead: 739
# Dead People Guessed Living: 235
# Total Patients: 1932
# Correct Guesses: 958
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5284679089026915
# Accuracy for Dead: 0.5252747252747253
# Accuracy for Living: 0.5294515910629655
# Living People Guessed Dead: 695
# Dead People Guessed Living: 216
# Total Patients: 1932
# Correct Guesses: 1021
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4974120082815735
# Accuracy for Dead: 0.5054945054945055
# Accuracy for Living: 0.4949221394719025
# Living People Guessed Dead: 746
# Dead People Guessed Living: 225
# Total Patients: 1932
# Correct Guesses: 961
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5064733298808908
# Accuracy for Dead: 0.5164835164835165
# Accuracy for Living: 0.5033875338753387
# Living People Guessed Dead: 733
# Dead People Guessed Living: 220
# Total Patients: 1931
# Correct Guesses: 978
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4904194717762817
# Accuracy for Dead: 0.48131868131868133
# Accuracy for Living: 0.4932249322493225
# Living People Guessed Dead: 748
# Dead People Guessed Living: 236
# Total Patients: 1931
# Correct Guesses: 947
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.490937338166753
# Accuracy for Dead: 0.46373626373626375
# Accuracy for Living: 0.4993224932249323
# Living People Guessed Dead: 739
# Dead People Guessed Living: 244
# Total Patients: 1931
# Correct Guesses: 948
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5002589331952356
# Accuracy for Dead: 0.4901098901098901
# Accuracy for Living: 0.5033875338753387
# Living People Guessed Dead: 733
# Dead People Guessed Living: 232
# Total Patients: 1931
# Correct Guesses: 966
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4927536231884058
# Accuracy for Dead: 0.4780701754385965
# Accuracy for Living: 0.497289972899729
# Living People Guessed Dead: 742
# Dead People Guessed Living: 238
# Total Patients: 1932
# Correct Guesses: 952
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5098343685300207
# Accuracy for Dead: 0.48464912280701755
# Accuracy for Living: 0.5176151761517616
# Living People Guessed Dead: 712
# Dead People Guessed Living: 235
# Total Patients: 1932
# Correct Guesses: 985
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4953416149068323
# Accuracy for Dead: 0.4780701754385965
# Accuracy for Living: 0.5006775067750677
# Living People Guessed Dead: 737
# Dead People Guessed Living: 238
# Total Patients: 1932
# Correct Guesses: 957
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5036231884057971
# Accuracy for Dead: 0.5241228070175439
# Accuracy for Living: 0.497289972899729
# Living People Guessed Dead: 742
# Dead People Guessed Living: 217
# Total Patients: 1932
# Correct Guesses: 973
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5170807453416149
# Accuracy for Dead: 0.5186813186813187
# Accuracy for Living: 0.5165876777251185
# Living People Guessed Dead: 714
# Dead People Guessed Living: 219
# Total Patients: 1932
# Correct Guesses: 999
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4974120082815735
# Accuracy for Dead: 0.45714285714285713
# Accuracy for Living: 0.5098171970209885
# Living People Guessed Dead: 724
# Dead People Guessed Living: 247
# Total Patients: 1932
# Correct Guesses: 961
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.49611600207146556
# Accuracy for Dead: 0.5164835164835165
# Accuracy for Living: 0.4898373983739837
# Living People Guessed Dead: 753
# Dead People Guessed Living: 220
# Total Patients: 1931
# Correct Guesses: 958
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5142413257379596
# Accuracy for Dead: 0.4835164835164835
# Accuracy for Living: 0.5237127371273713
# Living People Guessed Dead: 703
# Dead People Guessed Living: 235
# Total Patients: 1931
# Correct Guesses: 993
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5173485240807871
# Accuracy for Dead: 0.5230769230769231
# Accuracy for Living: 0.5155826558265583
# Living People Guessed Dead: 715
# Dead People Guessed Living: 217
# Total Patients: 1931
# Correct Guesses: 999
# Alive People: 1476
# Dead People: 455
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5152770585189022
# Accuracy for Dead: 0.512087912087912
# Accuracy for Living: 0.516260162601626
# Living People Guessed Dead: 714
# Dead People Guessed Living: 222
# Total Patients: 1931
# Correct Guesses: 995
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4989648033126294
# Accuracy for Dead: 0.5285087719298246
# Accuracy for Living: 0.4898373983739837
# Living People Guessed Dead: 753
# Dead People Guessed Living: 215
# Total Patients: 1932
# Correct Guesses: 964
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4922360248447205
# Accuracy for Dead: 0.4824561403508772
# Accuracy for Living: 0.49525745257452575
# Living People Guessed Dead: 745
# Dead People Guessed Living: 236
# Total Patients: 1932
# Correct Guesses: 951
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5015527950310559
# Accuracy for Dead: 0.5219298245614035
# Accuracy for Living: 0.49525745257452575
# Living People Guessed Dead: 745
# Dead People Guessed Living: 218
# Total Patients: 1932
# Correct Guesses: 969
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5031055900621118
# Accuracy for Dead: 0.5043859649122807
# Accuracy for Living: 0.502710027100271
# Living People Guessed Dead: 734
# Dead People Guessed Living: 226
# Total Patients: 1932
# Correct Guesses: 972
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5025879917184265
# Accuracy for Dead: 0.4901098901098901
# Accuracy for Living: 0.5064319566689235
# Living People Guessed Dead: 729
# Dead People Guessed Living: 232
# Total Patients: 1932
# Correct Guesses: 971
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.48757763975155277
# Accuracy for Dead: 0.48131868131868133
# Accuracy for Living: 0.4895057549085985
# Living People Guessed Dead: 754
# Dead People Guessed Living: 236
# Total Patients: 1932
# Correct Guesses: 942
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5160455486542443
# Accuracy for Dead: 0.45714285714285713
# Accuracy for Living: 0.5341909275558565
# Living People Guessed Dead: 688
# Dead People Guessed Living: 247
# Total Patients: 1932
# Correct Guesses: 997
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.49922320041429313
# Accuracy for Dead: 0.46813186813186813
# Accuracy for Living: 0.5088075880758808
# Living People Guessed Dead: 725
# Dead People Guessed Living: 242
# Total Patients: 1931
# Correct Guesses: 964
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5054375970999482
# Accuracy for Dead: 0.5098901098901099
# Accuracy for Living: 0.5040650406504065
# Living People Guessed Dead: 732
# Dead People Guessed Living: 223
# Total Patients: 1931
# Correct Guesses: 976
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5059554634904194
# Accuracy for Dead: 0.5142857142857142
# Accuracy for Living: 0.5033875338753387
# Living People Guessed Dead: 733
# Dead People Guessed Living: 221
# Total Patients: 1931
# Correct Guesses: 977
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.47360248447204967
# Accuracy for Dead: 0.49122807017543857
# Accuracy for Living: 0.46815718157181574
# Living People Guessed Dead: 785
# Dead People Guessed Living: 232
# Total Patients: 1932
# Correct Guesses: 915
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5150103519668737
# Accuracy for Dead: 0.49780701754385964
# Accuracy for Living: 0.5203252032520326
# Living People Guessed Dead: 708
# Dead People Guessed Living: 229
# Total Patients: 1932
# Correct Guesses: 995
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5031055900621118
# Accuracy for Dead: 0.5219298245614035
# Accuracy for Living: 0.497289972899729
# Living People Guessed Dead: 742
# Dead People Guessed Living: 218
# Total Patients: 1932
# Correct Guesses: 972
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4891304347826087
# Accuracy for Dead: 0.4605263157894737
# Accuracy for Living: 0.49796747967479676
# Living People Guessed Dead: 741
# Dead People Guessed Living: 246
# Total Patients: 1932
# Correct Guesses: 945
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4901656314699793
# Accuracy for Dead: 0.432967032967033
# Accuracy for Living: 0.5077860528097495
# Living People Guessed Dead: 727
# Dead People Guessed Living: 258
# Total Patients: 1932
# Correct Guesses: 947
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4989648033126294
# Accuracy for Dead: 0.5230769230769231
# Accuracy for Living: 0.4915368991198375
# Living People Guessed Dead: 751
# Dead People Guessed Living: 217
# Total Patients: 1932
# Correct Guesses: 964
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.505175983436853
# Accuracy for Dead: 0.512087912087912
# Accuracy for Living: 0.5030467163168585
# Living People Guessed Dead: 734
# Dead People Guessed Living: 222
# Total Patients: 1932
# Correct Guesses: 976
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.49456240290005177
# Accuracy for Dead: 0.5164835164835165
# Accuracy for Living: 0.4878048780487805
# Living People Guessed Dead: 756
# Dead People Guessed Living: 220
# Total Patients: 1931
# Correct Guesses: 955
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5106162610046608
# Accuracy for Dead: 0.46813186813186813
# Accuracy for Living: 0.5237127371273713
# Living People Guessed Dead: 703
# Dead People Guessed Living: 242
# Total Patients: 1931
# Correct Guesses: 986
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5002589331952356
# Accuracy for Dead: 0.49230769230769234
# Accuracy for Living: 0.502710027100271
# Living People Guessed Dead: 734
# Dead People Guessed Living: 231
# Total Patients: 1931
# Correct Guesses: 966
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.489648033126294
# Accuracy for Dead: 0.5043859649122807
# Accuracy for Living: 0.48509485094850946
# Living People Guessed Dead: 760
# Dead People Guessed Living: 226
# Total Patients: 1932
# Correct Guesses: 946
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4849896480331263
# Accuracy for Dead: 0.5175438596491229
# Accuracy for Living: 0.4749322493224932
# Living People Guessed Dead: 775
# Dead People Guessed Living: 220
# Total Patients: 1932
# Correct Guesses: 937
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5015527950310559
# Accuracy for Dead: 0.4868421052631579
# Accuracy for Living: 0.5060975609756098
# Living People Guessed Dead: 729
# Dead People Guessed Living: 234
# Total Patients: 1932
# Correct Guesses: 969
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5062111801242236
# Accuracy for Dead: 0.4956140350877193
# Accuracy for Living: 0.5094850948509485
# Living People Guessed Dead: 724
# Dead People Guessed Living: 230
# Total Patients: 1932
# Correct Guesses: 978
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5077639751552795
# Accuracy for Dead: 0.5164835164835165
# Accuracy for Living: 0.5050778605280974
# Living People Guessed Dead: 731
# Dead People Guessed Living: 220
# Total Patients: 1932
# Correct Guesses: 981
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4927536231884058
# Accuracy for Dead: 0.5186813186813187
# Accuracy for Living: 0.4847664184157075
# Living People Guessed Dead: 761
# Dead People Guessed Living: 219
# Total Patients: 1932
# Correct Guesses: 952
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5150103519668737
# Accuracy for Dead: 0.5274725274725275
# Accuracy for Living: 0.5111712931618145
# Living People Guessed Dead: 722
# Dead People Guessed Living: 215
# Total Patients: 1932
# Correct Guesses: 995
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.509062661833247
# Accuracy for Dead: 0.5186813186813187
# Accuracy for Living: 0.5060975609756098
# Living People Guessed Dead: 729
# Dead People Guessed Living: 219
# Total Patients: 1931
# Correct Guesses: 983
# Alive People: 1476
# Dead People: 455
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4940445365095805
# Accuracy for Dead: 0.5296703296703297
# Accuracy for Living: 0.4830623306233062
# Living People Guessed Dead: 763
# Dead People Guessed Living: 214
# Total Patients: 1931
# Correct Guesses: 954
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.48886587260486797
# Accuracy for Dead: 0.5054945054945055
# Accuracy for Living: 0.483739837398374
# Living People Guessed Dead: 762
# Dead People Guessed Living: 225
# Total Patients: 1931
# Correct Guesses: 944
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4922360248447205
# Accuracy for Dead: 0.49780701754385964
# Accuracy for Living: 0.4905149051490515
# Living People Guessed Dead: 752
# Dead People Guessed Living: 229
# Total Patients: 1932
# Correct Guesses: 951
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4994824016563147
# Accuracy for Dead: 0.42543859649122806
# Accuracy for Living: 0.5223577235772358
# Living People Guessed Dead: 705
# Dead People Guessed Living: 262
# Total Patients: 1932
# Correct Guesses: 965
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4730848861283644
# Accuracy for Dead: 0.47149122807017546
# Accuracy for Living: 0.4735772357723577
# Living People Guessed Dead: 777
# Dead People Guessed Living: 241
# Total Patients: 1932
# Correct Guesses: 914
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5129399585921325
# Accuracy for Dead: 0.4780701754385965
# Accuracy for Living: 0.5237127371273713
# Living People Guessed Dead: 703
# Dead People Guessed Living: 238
# Total Patients: 1932
# Correct Guesses: 991
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4979296066252588
# Accuracy for Dead: 0.4593406593406593
# Accuracy for Living: 0.5098171970209885
# Living People Guessed Dead: 724
# Dead People Guessed Living: 246
# Total Patients: 1932
# Correct Guesses: 962
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4989648033126294
# Accuracy for Dead: 0.49230769230769234
# Accuracy for Living: 0.5010155721056195
# Living People Guessed Dead: 737
# Dead People Guessed Living: 231
# Total Patients: 1932
# Correct Guesses: 964
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5
# Accuracy for Dead: 0.4879120879120879
# Accuracy for Living: 0.5037237643872715
# Living People Guessed Dead: 733
# Dead People Guessed Living: 233
# Total Patients: 1932
# Correct Guesses: 966
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5012946659761781
# Accuracy for Dead: 0.5362637362637362
# Accuracy for Living: 0.4905149051490515
# Living People Guessed Dead: 752
# Dead People Guessed Living: 211
# Total Patients: 1931
# Correct Guesses: 968
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.49145520455722425
# Accuracy for Dead: 0.47912087912087914
# Accuracy for Living: 0.49525745257452575
# Living People Guessed Dead: 745
# Dead People Guessed Living: 237
# Total Patients: 1931
# Correct Guesses: 949
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.502848265147592
# Accuracy for Dead: 0.4967032967032967
# Accuracy for Living: 0.5047425474254743
# Living People Guessed Dead: 731
# Dead People Guessed Living: 229
# Total Patients: 1931
# Correct Guesses: 971
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5062111801242236
# Accuracy for Dead: 0.4956140350877193
# Accuracy for Living: 0.5094850948509485
# Living People Guessed Dead: 724
# Dead People Guessed Living: 230
# Total Patients: 1932
# Correct Guesses: 978
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5181159420289855
# Accuracy for Dead: 0.4934210526315789
# Accuracy for Living: 0.5257452574525745
# Living People Guessed Dead: 700
# Dead People Guessed Living: 231
# Total Patients: 1932
# Correct Guesses: 1001
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5015527950310559
# Accuracy for Dead: 0.5307017543859649
# Accuracy for Living: 0.49254742547425473
# Living People Guessed Dead: 749
# Dead People Guessed Living: 214
# Total Patients: 1932
# Correct Guesses: 969
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4953416149068323
# Accuracy for Dead: 0.4649122807017544
# Accuracy for Living: 0.5047425474254743
# Living People Guessed Dead: 731
# Dead People Guessed Living: 244
# Total Patients: 1932
# Correct Guesses: 957
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4782608695652174
# Accuracy for Dead: 0.4747252747252747
# Accuracy for Living: 0.47935003385240355
# Living People Guessed Dead: 769
# Dead People Guessed Living: 239
# Total Patients: 1932
# Correct Guesses: 924
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4906832298136646
# Accuracy for Dead: 0.4703296703296703
# Accuracy for Living: 0.4969532836831415
# Living People Guessed Dead: 743
# Dead People Guessed Living: 241
# Total Patients: 1932
# Correct Guesses: 948
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4860248447204969
# Accuracy for Dead: 0.5252747252747253
# Accuracy for Living: 0.47393364928909953
# Living People Guessed Dead: 777
# Dead People Guessed Living: 216
# Total Patients: 1932
# Correct Guesses: 939
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4904194717762817
# Accuracy for Dead: 0.4461538461538462
# Accuracy for Living: 0.5040650406504065
# Living People Guessed Dead: 732
# Dead People Guessed Living: 252
# Total Patients: 1931
# Correct Guesses: 947
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4847229414810979
# Accuracy for Dead: 0.5010989010989011
# Accuracy for Living: 0.4796747967479675
# Living People Guessed Dead: 768
# Dead People Guessed Living: 227
# Total Patients: 1931
# Correct Guesses: 936
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4873122734334542
# Accuracy for Dead: 0.44395604395604393
# Accuracy for Living: 0.5006775067750677
# Living People Guessed Dead: 737
# Dead People Guessed Living: 253
# Total Patients: 1931
# Correct Guesses: 941
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5439958592132506
# Accuracy for Dead: 0.5504385964912281
# Accuracy for Living: 0.5420054200542005
# Living People Guessed Dead: 676
# Dead People Guessed Living: 205
# Total Patients: 1932
# Correct Guesses: 1051
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4953416149068323
# Accuracy for Dead: 0.49122807017543857
# Accuracy for Living: 0.49661246612466126
# Living People Guessed Dead: 743
# Dead People Guessed Living: 232
# Total Patients: 1932
# Correct Guesses: 957
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4974120082815735
# Accuracy for Dead: 0.5263157894736842
# Accuracy for Living: 0.48848238482384826
# Living People Guessed Dead: 755
# Dead People Guessed Living: 216
# Total Patients: 1932
# Correct Guesses: 961
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4922360248447205
# Accuracy for Dead: 0.5
# Accuracy for Living: 0.4898373983739837
# Living People Guessed Dead: 753
# Dead People Guessed Living: 228
# Total Patients: 1932
# Correct Guesses: 951
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4917184265010352
# Accuracy for Dead: 0.5164835164835165
# Accuracy for Living: 0.48408937034529453
# Living People Guessed Dead: 762
# Dead People Guessed Living: 220
# Total Patients: 1932
# Correct Guesses: 950
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5005175983436853
# Accuracy for Dead: 0.5318681318681319
# Accuracy for Living: 0.49085985104942453
# Living People Guessed Dead: 752
# Dead People Guessed Living: 213
# Total Patients: 1932
# Correct Guesses: 967
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5098343685300207
# Accuracy for Dead: 0.5494505494505495
# Accuracy for Living: 0.4976303317535545
# Living People Guessed Dead: 742
# Dead People Guessed Living: 205
# Total Patients: 1932
# Correct Guesses: 985
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5126877265665458
# Accuracy for Dead: 0.5076923076923077
# Accuracy for Living: 0.5142276422764228
# Living People Guessed Dead: 717
# Dead People Guessed Living: 224
# Total Patients: 1931
# Correct Guesses: 990
# Alive People: 1476
# Dead People: 455
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5137234593474883
# Accuracy for Dead: 0.5186813186813187
# Accuracy for Living: 0.5121951219512195
# Living People Guessed Dead: 720
# Dead People Guessed Living: 219
# Total Patients: 1931
# Correct Guesses: 992
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5199378560331435
# Accuracy for Dead: 0.5538461538461539
# Accuracy for Living: 0.5094850948509485
# Living People Guessed Dead: 724
# Dead People Guessed Living: 203
# Total Patients: 1931
# Correct Guesses: 1004
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5025879917184265
# Accuracy for Dead: 0.4868421052631579
# Accuracy for Living: 0.5074525745257452
# Living People Guessed Dead: 727
# Dead People Guessed Living: 234
# Total Patients: 1932
# Correct Guesses: 971
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.505175983436853
# Accuracy for Dead: 0.48464912280701755
# Accuracy for Living: 0.5115176151761518
# Living People Guessed Dead: 721
# Dead People Guessed Living: 235
# Total Patients: 1932
# Correct Guesses: 976
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4943064182194617
# Accuracy for Dead: 0.48026315789473684
# Accuracy for Living: 0.4986449864498645
# Living People Guessed Dead: 740
# Dead People Guessed Living: 237
# Total Patients: 1932
# Correct Guesses: 955
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4906832298136646
# Accuracy for Dead: 0.5350877192982456
# Accuracy for Living: 0.47696476964769646
# Living People Guessed Dead: 772
# Dead People Guessed Living: 212
# Total Patients: 1932
# Correct Guesses: 948
# Alive People: 1476
# Dead People: 456
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4855072463768116
# Accuracy for Dead: 0.4857142857142857
# Accuracy for Living: 0.4854434664861205
# Living People Guessed Dead: 760
# Dead People Guessed Living: 234
# Total Patients: 1932
# Correct Guesses: 938
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5015527950310559
# Accuracy for Dead: 0.4901098901098901
# Accuracy for Living: 0.5050778605280974
# Living People Guessed Dead: 731
# Dead People Guessed Living: 232
# Total Patients: 1932
# Correct Guesses: 969
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.5067287784679089
# Accuracy for Dead: 0.5186813186813187
# Accuracy for Living: 0.5030467163168585
# Living People Guessed Dead: 734
# Dead People Guessed Living: 219
# Total Patients: 1932
# Correct Guesses: 979
# Alive People: 1477
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.49145520455722425
# Accuracy for Dead: 0.4725274725274725
# Accuracy for Living: 0.497289972899729
# Living People Guessed Dead: 742
# Dead People Guessed Living: 240
# Total Patients: 1931
# Correct Guesses: 949
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.4981874676333506
# Accuracy for Dead: 0.4967032967032967
# Accuracy for Living: 0.4986449864498645
# Living People Guessed Dead: 740
# Dead People Guessed Living: 229
# Total Patients: 1931
# Correct Guesses: 962
# Alive People: 1476
# Dead People: 455
#
#
# 0.5
# Test Name: Test_Proportional_Random
# Overall Accuracy: 0.502848265147592
# Accuracy for Dead: 0.4989010989010989
# Accuracy for Living: 0.5040650406504065
# Living People Guessed Dead: 732
# Dead People Guessed Living: 228
# Total Patients: 1931
# Correct Guesses: 971
# Alive People: 1476
# Dead People: 455

# %%
# Calculate average accuracy
with open('test_proportional_random_runs.csv', 'r') as f:
    lines = f.readlines()
    all_accuracies = []
    for line in lines:
        split_line = line.split(',')
        accuracy = float(split_line[3])
        all_accuracies.append(accuracy)
    avg_accuracy = np.average(all_accuracies)
    print("Average accuracy is:", avg_accuracy)
# Out:
# Average accuracy is: 0.5004221254394627

# %%
# This proportional run-through builds a loaded coin that is run on the entirety of the dataset 
# as opposed to the split cross-val values that are 50-50 life and death
all_data = patientdata[['icustayid','mortality_90d']].drop_duplicates()
total_alive:int = all_data['mortality_90d'].value_counts()[0]
total_dead:int = all_data['mortality_90d'].value_counts()[1]
alive_proportion = total_alive / (total_alive + total_dead)
death_states = all_data['mortality_90d'].tolist()
correct_guesses = 0
rng.seed(123456789)
for i in range(0, len(death_states)):
    random_guess = 1
    # Generate proportional guess based on Randomly Uniform Distribution [0.0, 1.0]
    random_double = rng.random()
    # Suppose 60% of the people are alive. That means the code should say the person is alive
    # If a float between 0 and 0.5999999... is rolled, and dead otherwise
    if random_double < alive_proportion:
        random_guess = 0
    
    patient_status = death_states[i]
    # If the random guesser guesses correctly, add to the count
    if random_guess == patient_status:
        correct_guesses = correct_guesses + 1
print(correct_guesses/len(death_states))
# Out:
# 0.6387271117737502

# %%
a
